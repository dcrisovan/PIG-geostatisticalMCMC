# %% [markdown]
# # Tutorial 4: Initializing a small-scale chain

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from gstatsMCMC import Topography
from gstatsMCMC import MCMC
import gstatsim as gs
from sklearn.preprocessing import QuantileTransformer
import skgstat as skg
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# load compiled bed elevation measurements
df = pd.read_csv('PineIslandGriddedMASKED_cropped.csv')

# %%
# create a grid of x and y coordinates
x_uniq = np.unique(df.x)
y_uniq = np.unique(df.y)

xmin = np.min(x_uniq)
xmax = np.max(x_uniq)
ymin = np.min(y_uniq)
ymax = np.max(y_uniq)

cols = len(x_uniq)
rows = len(y_uniq)

resolution = 500

xx, yy = np.meshgrid(x_uniq, y_uniq)

# %%
# load other data
dhdt = df['dhdt'].values.reshape(xx.shape)
smb = df['smb'].values.reshape(xx.shape)
velx = df['velx'].values.reshape(xx.shape)
vely = df['vely'].values.reshape(xx.shape)
bedmap_mask = df['bedmap_mask'].values.reshape(xx.shape)
bedmachine_thickness = df['bedmachine_thickness'].values.reshape(xx.shape)
bedmap_surf = df['bedmap_surf'].values.reshape(xx.shape)
highvel_mask = df['final_mask'].values.reshape(xx.shape)
bedmachine_bed = df['bedmap_surf'].values.reshape(xx.shape) - bedmachine_thickness
bedmap_bed = df['bedmap_bed'].values.reshape(xx.shape)

# %%
# create conditioning data
# bed elevation measurement in grounded ice region, and bedmap topography elsewhere
cond_bed = np.where(bedmap_mask == 1, df['bed'].values.reshape(xx.shape), bedmap_bed)
df['cond_bed'] = cond_bed.flatten()
# create a mask of conditioning data
data_mask = ~np.isnan(cond_bed)

# %% [markdown]
# __step1: calculate the trend__

# %%
initial_bed = np.loadtxt('PIG_bed_2000000.txt')

# %%
import scipy as sp
trend = sp.ndimage.gaussian_filter(initial_bed, sigma=10)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4),gridspec_kw={'width_ratios': [1, 1.3]} )

axes[0].pcolormesh(xx, yy, initial_bed, vmax=1500,vmin=-3500)
axes[0].set_title('initial bed')
axes[0].set_aspect('equal')

bedfig = axes[1].pcolormesh(xx, yy, trend, vmax=1500,vmin=-3500)
axes[1].set_title('topography trend (smoothed initial bed)')
axes[1].set_aspect('equal')
fig.colorbar(bedfig, ax=axes[1])

# %% [markdown]
# __step2: calculate detrended variogram__

# %%
# ##################WHEN NO DETREND###################
# #normalize the conditioning bed data, saved to df['Nbed']
data = df['cond_bed'].values.reshape(-1,1)
nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
transformed_data = nst_trans.transform(data)
df['Nbed'] = transformed_data

# %%
# normalize the de-trended conditioning data, saved to df['Nbed_residual']
#df['cond_bed_residual']=df['cond_bed'].values-trend.flatten()
#data = df['cond_bed_residual'].values.reshape(-1,1)
#nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
#transformed_data = nst_trans.transform(data)
#df['Nbed_residual'] = transformed_data

# %%
###################WHEN NO DETREND###################
df_sampled = df.sample(frac=0.05, random_state=42)
df_sampled = df_sampled[df_sampled["cond_bed"].isnull() == False]
df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]
coords = df_sampled[['x','y']].values
values = df_sampled['Nbed']

# randomly drop out 95% of coordinates. Decrease this value if you have a lot of data and it takes a long time to run
#df_sampled = df.sample(frac=0.05, random_state=42)
#df_sampled = df_sampled[df_sampled["cond_bed_residual"].isnull() == False]
#df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]

# compute experimental (isotropic) variogram
#coords = df_sampled[['x','y']].values
#values = df_sampled['Nbed_residual']

maxlag = 20000      # maximum range distance
n_lags = 70         # num of bins (try decreasing if this is taking too long)

# compute variogram
V1 = skg.Variogram(coords, values, bin_func='even', n_lags=n_lags, maxlag=maxlag, normalize=False, model='matern')

# extract variogram values
xdata = V1.bins
ydata = V1.experimental

V1_p = V1.parameters

# evaluate models
xi = np.linspace(0, xdata[-1], n_lags) 
y_mtn = [skg.models.matern(h, V1_p[0], V1_p[1], V1_p[2], V1_p[3]) for h in xi]
# variogram parameter is [range, sill, shape, nugget] for matern model.

plt.figure(figsize=(6,4))
plt.scatter(xdata, ydata, s=12, c='g')
plt.plot(xi, y_mtn,'b-.', label='Matern variogram model')
plt.title('Isotropic Experimental Variogram')
plt.xlabel('Lag (m)'); plt.ylabel('Semivariance')
plt.show()

# %%
V1_p
# Out:
# [19999.999999999996, 0.2422872674756321, 3.571204931018212, 0]

# %%
###################When load sgs-generated bed as initial bed###################
# load the initial bed, make sure no bed in grounded ice region is higher altitude than ice surface
#sgs_bed = np.loadtxt('sgs_bed_totten_cropped.txt')
#thickness = bedmap_surf - sgs_bed
#sgs_bed = np.where((thickness<=0)&(bedmap_mask==1), bedmap_surf-1, sgs_bed)

# %% [markdown]
# ### Then initiating the SGS chain

# %% [markdown]
# The first 4 initialization process are very similar to chain_crf, please refers to Tutorial 3 for detailed information

# %%
grounded_ice_mask = (bedmap_mask == 1)

# %% [markdown]
# step3: set up the chain
# - change initial bed
# - set normal transformation
# - set trend

# %%
###################When start with a sgs-generated bed###################
#smallScaleChain = MCMC.chain_sgs(xx, yy, sgs_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)

# %%
smallScaleChain = MCMC.chain_sgs(xx, yy, initial_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)
# Out:
# before running the chain, please set where the block update will be using the object's function set_update_in_region(region_mask) and set_update_region(update_in_region)
# please also set up the sgs parameters using set_sgs_param(self, block_size, sgs_param)
# then please set up the loss function using either set_loss_type or set_loss_func

# %%
smallScaleChain.set_update_region(True,highvel_mask)
# Out:
# the update blocks is set to be randomly generated for any locations inside the given region

# %%
smallScaleChain.set_loss_type(map_func='sumsquare', sigma_mc=4.1, massConvInRegion=True)

# %%
# set up the block sizes
min_block_x = 3
max_block_x = 17
min_block_y = 3
max_block_y = 17
smallScaleChain.set_block_sizes(min_block_x, max_block_x, min_block_y, max_block_y)

# %% [markdown]
# Sequential Gaussian Simulation is set to perform on the normalized data. This nst_trans is an object of the QuantileTranformer class in scikit-learn python library. The *fit_variogram* function returns a nst_trans object, which could be directly used here

# %%
###################When no normal score transformation###################
# do_transform could be set to true for both detrend and no detrend options
# recommend to set it to true
smallScaleChain.set_normal_transformation(nst_trans, do_transform=False)

# %%
#smallScaleChain.set_normal_transformation(nst_trans, do_transform=True)

# %% [markdown]
# When running the SGS chain, it is possible to 'detrend' the topography.
#
# Detrend topography refers to substracting a pre-defined trend from the topography map, where the trend suppose to represent long-wavelength features that violate stationary properties of SGS. If choose to detrend the topography, the argument *detrend_map* need to be set to True, and the argument *trend* need to be a 2D numpy array representing the topography trend

# %%
###################WHEN NO DETREND###################
smallScaleChain.set_trend(trend = [], detrend_map = False)

# %%
#smallScaleChain.set_trend(trend = trend, detrend_map = True)

# %%
smallScaleChain.set_variogram('Matern',V1_p[0],V1_p[1],0,isotropic=True,vario_smoothness=V1_p[2])
# Out:
# the variogram is set to type Matern

# %%
smallScaleChain.set_sgs_param(48, 30e3, sgs_rand_dropout_on=False)
# Out:
# because the sgs_rand_dropout_on is set to False, the dropout_rate is automatically set to 0

# %% [markdown]
# __step4: run the chain, check if the loss is correct__

# %%
# test the new sgs
beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run_newsgs(n_iter=20000, only_save_last_bed=True, info_per_iter = 1000)
# Out:
# i: 0 mc loss: 2.414e+06 loss: 2.414e+06 acceptance rate: 0.0
# i: 1000 mc loss: 2.409e+06 loss: 2.409e+06 acceptance rate: 0.16683316683316685
# i: 2000 mc loss: 2.406e+06 loss: 2.406e+06 acceptance rate: 0.17641179410294852
# i: 3000 mc loss: 2.400e+06 loss: 2.400e+06 acceptance rate: 0.1769410196601133
# i: 4000 mc loss: 2.382e+06 loss: 2.382e+06 acceptance rate: 0.17945513621594603
# i: 5000 mc loss: 2.378e+06 loss: 2.378e+06 acceptance rate: 0.17776444711057787
# i: 6000 mc loss: 2.375e+06 loss: 2.375e+06 acceptance rate: 0.17947008831861355
# i: 7000 mc loss: 2.370e+06 loss: 2.370e+06 acceptance rate: 0.1788315954863591
# i: 8000 mc loss: 2.366e+06 loss: 2.366e+06 acceptance rate: 0.18060242469691287
# i: 9000 mc loss: 2.364e+06 loss: 2.364e+06 acceptance rate: 0.17620264415064993
# i: 10000 mc loss: 2.361e+06 loss: 2.361e+06 acceptance rate: 0.17718228177182282
# i: 11000 mc loss: 2.360e+06 loss: 2.360e+06 acceptance rate: 0.17643850559040086
# i: 12000 mc loss: 2.358e+06 loss: 2.358e+06 acceptance rate: 0.17681859845012915
# i: 13000 mc loss: 2.357e+06 loss: 2.357e+06 acceptance rate: 0.17560187677870934
# i: 14000 mc loss: 2.355e+06 loss: 2.355e+06 acceptance rate: 0.17505892436254553
# i: 15000 mc loss: 2.353e+06 loss: 2.353e+06 acceptance rate: 0.17532164522365176
# i: 16000 mc loss: 2.351e+06 loss: 2.351e+06 acceptance rate: 0.1742391100556215
# i: 17000 mc loss: 2.349e+06 loss: 2.349e+06 acceptance rate: 0.17457796600199987
# i: 18000 mc loss: 2.346e+06 loss: 2.346e+06 acceptance rate: 0.1737681239931115
# i: 19000 mc loss: 2.344e+06 loss: 2.344e+06 acceptance rate: 0.1742539866322825

# %%
plt.plot(loss)
plt.title('MCMC Small-Scale Chain Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.savefig('smallScale_PIG_loss.png', dpi = 300, bbox_inches = 'tight')

# %%
plt.pcolormesh(xx,yy,beds,vmax=1500,vmin=-1500)

# %%
n_iter = 1000

for i in range(0,20):
    beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run_newsgs(n_iter=n_iter, only_save_last_bed=True, info_per_iter = 200)
    
    # save all the data in every run of the algorithm
    np.savetxt('Totten_sgs1_loss_'+str(i*n_iter)+'.txt', loss)
    np.savetxt('Totten_sgs1_steps_'+str(i*n_iter)+'.txt', steps) 
    np.savetxt('Totten_sgs1_bed_'+str(i*n_iter)+'.txt',beds)
    
    # set up the next chain
    smallScaleChain.initial_bed = beds
# Out:
# i: 0 mc loss: 1.274e+06 loss: 1.274e+06 acceptance rate: 1.0
# i: 200 mc loss: 1.274e+06 loss: 1.274e+06 acceptance rate: 0.13432835820895522
# i: 400 mc loss: 1.273e+06 loss: 1.273e+06 acceptance rate: 0.12718204488778054
# i: 600 mc loss: 1.273e+06 loss: 1.273e+06 acceptance rate: 0.14143094841930118
# i: 800 mc loss: 1.273e+06 loss: 1.273e+06 acceptance rate: 0.1373283395755306
# i: 0 mc loss: 1.272e+06 loss: 1.272e+06 acceptance rate: 1.0
# i: 200 mc loss: 1.272e+06 loss: 1.272e+06 acceptance rate: 0.13432835820895522
# i: 400 mc loss: 1.272e+06 loss: 1.272e+06 acceptance rate: 0.10972568578553615
# i: 600 mc loss: 1.271e+06 loss: 1.271e+06 acceptance rate: 0.12312811980033278
# i: 800 mc loss: 1.271e+06 loss: 1.271e+06 acceptance rate: 0.1285892634207241
# i: 0 mc loss: 1.271e+06 loss: 1.271e+06 acceptance rate: 0.0
# i: 200 mc loss: 1.271e+06 loss: 1.271e+06 acceptance rate: 0.14427860696517414
# i: 400 mc loss: 1.270e+06 loss: 1.270e+06 acceptance rate: 0.14713216957605985
# i: 600 mc loss: 1.270e+06 loss: 1.270e+06 acceptance rate: 0.1464226289517471
# i: 800 mc loss: 1.269e+06 loss: 1.269e+06 acceptance rate: 0.149812734082397
# i: 0 mc loss: 1.269e+06 loss: 1.269e+06 acceptance rate: 0.0
# i: 200 mc loss: 1.269e+06 loss: 1.269e+06 acceptance rate: 0.12437810945273632
# i: 400 mc loss: 1.268e+06 loss: 1.268e+06 acceptance rate: 0.12967581047381546
# i: 600 mc loss: 1.268e+06 loss: 1.268e+06 acceptance rate: 0.11813643926788686
# i: 800 mc loss: 1.268e+06 loss: 1.268e+06 acceptance rate: 0.12609238451935081
# i: 0 mc loss: 1.268e+06 loss: 1.268e+06 acceptance rate: 0.0
# i: 200 mc loss: 1.267e+06 loss: 1.267e+06 acceptance rate: 0.14427860696517414
# i: 400 mc loss: 1.267e+06 loss: 1.267e+06 acceptance rate: 0.11471321695760599
# i: 600 mc loss: 1.267e+06 loss: 1.267e+06 acceptance rate: 0.12146422628951747
# i: 200 mc loss: 1.255e+06 loss: 1.255e+06 acceptance rate: 0.11940298507462686
# i: 400 mc loss: 1.254e+06 loss: 1.254e+06 acceptance rate: 0.11471321695760599
# i: 600 mc loss: 1.254e+06 loss: 1.254e+06 acceptance rate: 0.10815307820299501
# i: 800 mc loss: 1.254e+06 loss: 1.254e+06 acceptance rate: 0.11735330836454431
# i: 0 mc loss: 1.254e+06 loss: 1.254e+06 acceptance rate: 0.0
# i: 200 mc loss: 1.254e+06 loss: 1.254e+06 acceptance rate: 0.12437810945273632
# i: 400 mc loss: 1.254e+06 loss: 1.254e+06 acceptance rate: 0.12718204488778054
# i: 600 mc loss: 1.253e+06 loss: 1.253e+06 acceptance rate: 0.13477537437603992
# i: 800 mc loss: 1.253e+06 loss: 1.253e+06 acceptance rate: 0.14606741573033707

# %%
bed1 = np.loadtxt('PIG_bed_2000000.txt')
plt.pcolormesh(xx,yy,bed1,vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
plt.pcolormesh(xx,yy,beds,vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
fig, ax = plt.subplots(figsize=(6, 5))

im = ax.pcolormesh(xx, yy, beds, vmin=-2100, vmax=1250, cmap='gist_earth')
ax.set_title('MCMC Final Realization')
ax.set_xlabel('Polar stereographic x (m)')
ax.set_ylabel('Polar stereographic y (m)')
plt.ticklabel_format(style='sci', axis='both', scilimits=(6,6))
ax.set_xticks(np.linspace(xmin, xmax, 5))
ax.set_yticks(np.linspace(ymin, ymax, 5))

divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.1)
cbar = plt.colorbar(im, ticks=np.linspace(-3000, 1000, 11), cax=cax)
cbar.set_label("Bed elevation (m)", rotation=270, labelpad=15)
ax.axis('scaled')

plt.tight_layout()
plt.show()

plt.savefig('MCMCFinalRealization.png', dpi = 300, bbox_inches = 'tight')

# %%
plt.pcolormesh(xx,yy,beds-bed1, cmap='RdBu',vmax=200,vmin=-200)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
plt.pcolormesh(xx,yy,beds-bed1>1)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
bed2 = np.loadtxt('PIG_bed_2000000.txt')
plt.pcolormesh(xx,yy,bed2 - cond_bed,vmax=1,vmin=-1,cmap='RdBu')
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
# mass conservation residual

# %%
large_loss = np.loadtxt("PIG_loss_combined.txt")
plt.plot(large_loss)
plt.title('MCMC Large-Scale Chain Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.savefig('largeScale_PIG_loss.png', dpi = 300, bbox_inches = 'tight')
